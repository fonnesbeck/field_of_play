# %%
import pybaseball
import  pandas as pd

# %%
sept24_data =pybaseball.statcast(start_dt="2024-09-01", end_dt="2024-09-30")
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/30 [00:00<?, ?it/s]/var/home/fonnesbeck/repos/field_of_play/.pixi/envs/default/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 1/30 [00:07<03:40,  7.60s/it]/var/home/fonnesbeck/repos/field_of_play/.pixi/envs/default/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ...

# %%
sept24_data.head()
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 198         FF 2024-09-30           97.4           -2.1           4.88
# 204         SL 2024-09-30           90.7          -2.14           5.06
# 210         SL 2024-09-30           91.1          -2.07           5.14
# 215         SL 2024-09-30           91.3          -2.05           5.07
# 220         SL 2024-09-30           89.1          -2.13           5.15
#
#      player_name  batter  pitcher     events      description  ...  \
# 198  Díaz, Edwin  518595   621242  field_out    hit_into_play  ...
# 204  Díaz, Edwin  518595   621242        NaN             ball  ...
# 210  Díaz, Edwin  518595   621242        NaN  swinging_strike  ...
# 215  Díaz, Edwin  518595   621242        NaN             ball  ...
# 220  Díaz, Edwin  518595   621242        NaN  swinging_strike  ...
#
#      n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 198                    1                                 4
# ...
